# %% [markdown]
# # 2. Cluster Analysis
#
# Using the clusters created in program 1, identify which clusters best fit the data and areas requiring cleanup.

# %%
# Initialize necessary packages
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AgglomerativeClustering
import re

# Scroll through larger dataframes (more necessary for the HDBSCAN output
from IPython.display import display, HTML

# %% [markdown]
# ## Load Clustered Data
#
# Begin by loading in the Excel files containing the clustered data. Save them as pandas data frames.

# %%
# Load KMeans Clustered Data
kmeans_19 = pd.read_excel('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/kmeans.xlsx',
                          sheet_name = "cluster_19")

kmeans_42 = pd.read_excel('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/kmeans.xlsx',
                          sheet_name = "cluster_42")

# Load HDBSCAN
hdb_scan = pd.read_excel('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/hdbscan.xlsx',
                         sheet_name = 'umap-cosine-hdbscan')

# %% [markdown]
# ## Identify Most Commonly Used Words by Cluster
#
# Removing stopwords, identify the most commonly used words by each cluster. This will provide us with a better sense of the categories the clusters grouped the baby products into.
#
# Besides just word frequency, we can also use other methods to potentially pull more meaningful words from each cluster. Because of the pre-processing in program 1 as well as teh removal of stopwords here, this may not be necessary. However, we will use this method and analyze how it performs compared to raw word frequency.

# %%
# Define functions to perform the above actions

# The following function removes stopwords from the analysis (also does additional processing on text, but this
# was already taken care of in the first program, so it shouldn't do anything)
def preprocess(text):
    # Confirm text is a string
    if not isinstance(text, str):
        return []
    # Lowercase and remove non-alphabetic characters
    words = re.findall(r'\b[a-z]{2,}\b', text.lower())
    # Remove stop words
    return [word for word in words if word not in ENGLISH_STOP_WORDS]

# Define function for counting the most frequently used words
def get_top_words(df, cluster_col, tokens_col, top_n=3):
    top_words = {}
    for cluster in df[cluster_col].unique():
        words = [word for tokens in df[df[cluster_col] == cluster][tokens_col] for word in tokens]
        most_common = [word for word, _ in Counter(words).most_common(top_n)]
        top_words[cluster] = most_common
    return top_words

# %%
# Use TF-IDF to identify more meaningful frequently used words
def get_tfidf_top_words(df, cluster_col, tokens_col, top_n=3):
    tfidf_top_words = []

    for cluster in sorted(df[cluster_col].dropna().unique()):
        # Filter rows for this cluster
        cluster_df = df[df[cluster_col] == cluster]

        # Reconstruct raw text from tokens
        cluster_docs = cluster_df[tokens_col].apply(lambda tokens: ' '.join(tokens))

        # Skip empty clusters
        if cluster_docs.empty:
            continue

        # Vectorize using TF-IDF
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(cluster_docs)
        feature_names = vectorizer.get_feature_names_out()

        # Compute average TF-IDF per word in this cluster
        tfidf_means = tfidf_matrix.mean(axis=0).A1  # convert sparse matrix to array
        top_indices = tfidf_means.argsort()[::-1][:top_n]
        top_words = [feature_names[i] for i in top_indices]

        tfidf_top_words.append({
            'cluster': cluster,
            'top_words_tfidf': top_words
        })

    return pd.DataFrame(tfidf_top_words)

# %% [markdown]
# ### K-Means: 19
#
# Identify the most frequently used words for the K-Means = 19 clusters dataset.

# %%
# Pre-process text
kmeans_19['tokens'] = kmeans_19['text'].apply(preprocess)

# Identify the most frequently used words from each cluster
top_words_dict = get_top_words(kmeans_19, 'cluster', 'tokens', top_n=3)

# Map top words back to each row
kmeans_19['top_words'] = kmeans_19['cluster'].map(top_words_dict).apply(lambda words: ', '.join(words))

# %%
# Print out the top 3 words for each cluster

# Keep only necessary columns
df_cluster_words_19 = kmeans_19[['cluster', 'top_words']].copy()

# Convert top words to a tuple and only get unique instances of clusters and top words
df_cluster_words_19['top_words_tuple'] = df_cluster_words_19['top_words'].apply(lambda x: tuple(x))
df_cluster_words_19 = df_cluster_words_19.drop_duplicates(subset=['cluster', 'top_words_tuple'])

# Drop the tuple column
df_cluster_words_19 = df_cluster_words_19.drop(columns='top_words_tuple')

# Sort by cluster
df_cluster_words_19 = df_cluster_words_19.sort_values(by='cluster').reset_index(drop=True)

df_cluster_words_19.head(100)
# Out:
#     cluster                         top_words
# 0         0           accessories, car, seats
# 1         1     activity, entertainment, gyms
# 2         2      blankets, swaddling, nursery
# 3         3           nursery, wall, stickers
# 4         4           care, hair, accessories
# 5         5              feeding, solid, cups
# 6         6           diaper, bags, diapering
# 7         7         diapering, diapers, cloth
# 8         8               bibs, feeding, burp
# 9         9            training, potty, pants
# 10       10          bedding, nursery, sheets
# 11       11          feeding, bottle, bottles
# 12       12    feeding, breastfeeding, breast
# 13       13       nursery, furniture, storage
# 14       14             safety, guards, locks
# 15       15  accessories, strollers, standard
# 16       16             care, bathing, towels
# 17       17     teethers, pacifiers, teething
# 18       18                 gifts, gift, sets

# %% [markdown]
# Now us TF-IDF and compare results.

# %%
# Identify the most frequently used words from each cluster
top_words_dict_tfidf = get_tfidf_top_words(kmeans_19, 'cluster', 'tokens', top_n=3)

# SMerge tfidf top words back onto your original dataframe by cluster
kmeans_19 = kmeans_19.merge(top_words_dict_tfidf, on = 'cluster', how = 'left')

# Svae top_words_tfidf as a readable string
kmeans_19['top_words_tfidf'] = kmeans_19['top_words_tfidf'].apply(
    lambda words: ', '.join(words) if isinstance(words, list) else ''
)

# %%
# Print out the top 3 words for each cluster

# Keep only necessary columns
df_cluster_words_19_tfidf = kmeans_19[['cluster', 'top_words_tfidf']].copy()

# Convert top words to a tuple and only get unique instances of clusters and top words
df_cluster_words_19_tfidf['top_words_tuple'] = df_cluster_words_19_tfidf['top_words_tfidf'].apply(lambda x: tuple(x))
df_cluster_words_19_tfidf = df_cluster_words_19_tfidf.drop_duplicates(subset=['cluster', 'top_words_tuple'])

# Drop the tuple column
df_cluster_words_19_tfidf = df_cluster_words_19_tfidf.drop(columns='top_words_tuple')

# Sort by cluster
df_cluster_words_19_tfidf = df_cluster_words_19_tfidf.sort_values(by='cluster').reset_index(drop=True)

df_cluster_words_19_tfidf.head(100)
# Out:
#     cluster                   top_words_tfidf
# 0         0           accessories, seats, car
# 1         1     activity, entertainment, gyms
# 2         2      blankets, swaddling, bedding
# 3         3           wall, stickers, nursery
# 4         4           hair, care, accessories
# 5         5              feeding, solid, cups
# 6         6           diapering, bags, diaper
# 7         7         diapering, diapers, cloth
# 8         8         bibs, feeding, highchairs
# 9         9            training, potty, pants
# 10       10          bedding, sheets, nursery
# 11       11          feeding, bottle, bottles
# 12       12    breastfeeding, feeding, breast
# 13       13       nursery, storage, furniture
# 14       14             safety, locks, guards
# 15       15  strollers, accessories, standard
# 16       16             care, towels, bathing
# 17       17     teethers, pacifiers, teething
# 18       18                 gifts, gift, sets

# %% [markdown]
# ### K-Means: 42
#
# Identify the most frequently used words for the K-Means = 42 clusters dataset.

# %%
# Pre-process text
kmeans_42['tokens'] = kmeans_42['text'].apply(preprocess)

# Identify the most frequently used words from each cluster
top_words_dict = get_top_words(kmeans_42, 'cluster', 'tokens', top_n=3)

# Map top words back to each row
kmeans_42['top_words'] = kmeans_42['cluster'].map(top_words_dict).apply(lambda words: ', '.join(words))

# %%
# Print out the top 3 words for each cluster

# Keep only necessary columns
df_cluster_words_42 = kmeans_42[['cluster', 'top_words']].copy()

# Convert top words to a tuple and only get unique instances of clusters and top words
df_cluster_words_42['top_words_tuple'] = df_cluster_words_42['top_words'].apply(lambda x: tuple(x))
df_cluster_words_42 = df_cluster_words_42.drop_duplicates(subset=['cluster', 'top_words_tuple'])

# Drop the tuple column
df_cluster_words_42 = df_cluster_words_42.drop(columns='top_words_tuple')

# Sort by cluster
df_cluster_words_42 = df_cluster_words_42.sort_values(by='cluster').reset_index(drop=True)

df_cluster_words_42.head(100)
# Out:
#     cluster                         top_words
# 0         0         cloth, diapers, diapering
# 1         1       storage, furniture, nursery
# 2         2      blankets, swaddling, nursery
# 3         3              feeding, solid, cups
# 4         4       pillows, nursery, maternity
# 5         5           wall, stickers, nursery
# 6         6           care, hair, accessories
# 7         7               gates, gate, safety
# 8         8  strollers, accessories, standard
# 9         9                care, health, kids
# 10       10                 gifts, gift, sets
# 11       11            bedding, nursery, sets
# 12       12            training, potty, pants
# 13       13           accessories, car, seats
# 14       14          feeding, bottle, bottles
# 15       15              care, grooming, skin
# 16       16         diapering, wipes, holders
# 17       17        safety, leashes, harnesses
# 18       18              bathing, care, soaps
# 19       19     teethers, pacifiers, teething
# 20       20             locks, safety, guards
# 21       21                bibs, burp, cloths
# 22       22           diaper, bags, diapering
# 23       23          nursery, wall, furniture
# 24       24          bedding, sheets, nursery
# 25       25   breastfeeding, feeding, nursing
# 26       26        highchairs, booster, seats
# 27       27    breast, breastfeeding, feeding
# 28       28         swings, bouncers, jumpers
# 29       29              corner, edge, guards
# 30       30                           nursery
# 31       31  accessories, strollers, stroller
# 32       32           monitors, safety, video
# 33       33     activity, entertainment, gyms
# 34       34           diaper, bags, diapering
# 35       35              feeding, foods, food
# 36       36            beds, toddler, nursery
# 37       37         gear, travel, accessories
# 38       38             feeding, solid, place
# 39       39          changing, portable, pads
# 40       40       towels, washcloths, bathing
# 41       41            covers, pads, changing

# %% [markdown]
# Now use TF-IDF to compare results.

# %%
# Identify the most frequently used words from each cluster
top_words_dict_tfidf = get_tfidf_top_words(kmeans_42, 'cluster', 'tokens', top_n=3)

# SMerge tfidf top words back onto your original dataframe by cluster
kmeans_42 = kmeans_42.merge(top_words_dict_tfidf, on = 'cluster', how = 'left')

# Svae top_words_tfidf as a readable string
kmeans_42['top_words_tfidf'] = kmeans_42['top_words_tfidf'].apply(
    lambda words: ', '.join(words) if isinstance(words, list) else ''
)

# %%
# Print out the top 3 words for each cluster

# Keep only necessary columns
df_cluster_words_42_tfidf = kmeans_42[['cluster', 'top_words_tfidf']].copy()

# Convert top words to a tuple and only get unique instances of clusters and top words
df_cluster_words_42_tfidf['top_words_tuple'] = df_cluster_words_42_tfidf['top_words_tfidf'].apply(lambda x: tuple(x))
df_cluster_words_42_tfidf = df_cluster_words_42_tfidf.drop_duplicates(subset=['cluster', 'top_words_tuple'])

# Drop the tuple column
df_cluster_words_42_tfidf = df_cluster_words_42_tfidf.drop(columns='top_words_tuple')

# Sort by cluster
df_cluster_words_42_tfidf = df_cluster_words_42_tfidf.sort_values(by='cluster').reset_index(drop=True)

df_cluster_words_42_tfidf.head(100)
# Out:
#     cluster                     top_words_tfidf
# 0         0              diapers, cloth, covers
# 1         1    storage, organization, furniture
# 2         2        blankets, swaddling, bedding
# 3         3                feeding, cups, solid
# 4         4         pillows, nursery, maternity
# 5         5             nursery, stickers, wall
# 6         6             care, hair, accessories
# 7         7            gates, extensions, stair
# 8         8    strollers, accessories, standard
# 9         9          care, health, thermometers
# 10       10                   gift, gifts, sets
# 11       11              bedding, sets, nursery
# 12       12              training, potty, pants
# 13       13             accessories, seats, car
# 14       14            feeding, bottle, bottles
# 15       15                care, grooming, skin
# 16       16      diapering, disposable, diapers
# 17       17         safety, bathroom, harnesses
# 18       18                bathing, care, soaps
# 19       19       teethers, pacifiers, teething
# 20       20               locks, guards, safety
# 21       21                  bibs, cloths, burp
# 22       22              totes, diapering, bags
# 23       23              nursery, wall, mobiles
# 24       24            sheets, bedding, nursery
# 25       25     feeding, breastfeeding, nursing
# 26       26          highchairs, seats, booster
# 27       27      feeding, breastfeeding, breast
# 28       28           swings, bouncers, jumpers
# 29       29                safety, edge, guards
# 30       30                             nursery
# 31       31  accessories, strollers, organizers
# 32       32             monitors, safety, video
# 33       33            activity, gyms, playmats
# 34       34             diapering, bags, diaper
# 35       35                feeding, foods, food
# 36       36            beds, toddler, furniture
# 37       37         gear, accessories, carriers
# 38       38               feeding, solid, place
# 39       39           diapering, pads, portable
# 40       40          towels, washcloths, hooded
# 41       41             covers, pads, diapering

# %% [markdown]
# ### HDBSCAN: 235
#
# Identify the most frequently used words for the HDBSDCAN Procedure which produced 235 clusters.

# %%
# Pre-process text
hdb_scan['tokens'] = hdb_scan['text'].apply(preprocess)

# Identify the most frequently used words from each cluster
top_words_dict = get_top_words(hdb_scan, 'cluster', 'tokens', top_n=3)

# Map top words back to each row
hdb_scan['top_words'] = hdb_scan['cluster'].map(top_words_dict).apply(lambda words: ', '.join(words))

# %%
# Print out the top 3 words for each cluster

# Keep only necessary columns
df_cluster_words_hdbscan= hdb_scan[['cluster', 'top_words']].copy()

# Convert top words to a tuple and only get unique instances of clusters and top words
df_cluster_words_hdbscan['top_words_tuple'] = df_cluster_words_hdbscan['top_words'].apply(lambda x: tuple(x))
df_cluster_words_hdbscan = df_cluster_words_hdbscan.drop_duplicates(subset=['cluster', 'top_words_tuple'])

# Drop the tuple column
df_cluster_words_hdbscan = df_cluster_words_hdbscan.drop(columns='top_words_tuple')

# Sort by cluster
df_cluster_words_hdbscan = df_cluster_words_hdbscan.sort_values(by='cluster').reset_index(drop=True)

# Make it possible to scroll through this dataframe
# Display the DataFrame in a scrollable box
display(HTML(df_cluster_words_hdbscan.to_html(
    max_rows=300, notebook=True, index=False, justify='center',
    classes='scrollable-table', escape=False, table_id='cluster_table'
)))

# Inject some CSS to enable scrollable output
display(HTML('''
<style>
.scrollable-table {
    display: block;
    max-height: 400px;
    overflow-y: auto;
    border: 1px solid #ccc;
    padding: 10px;
}
</style>
'''))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe scrollable-table" id="cluster_table">
#   <thead>
#     <tr style="text-align: center;">
#       <th>cluster</th>
#       <th>top_words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-1</td>
#       <td>bedding, nursery, accessories</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>nursery, blankets, swaddling</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>bedding, sheets, crib</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>care, hair, accessories</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nursery, furniture, storage</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>gifts, keepsakes, hand</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>bedding, toddler, nursery</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>accessories, stroller, strollers</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nursery, furniture, playards</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>accessories, stroller, strollers</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>diaper, diapering, stackers</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>accessories, travel, gear</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>cloth, diapering, diapers</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>hanging, nursery, storage</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>nursery, wall, letters</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>accessories, car, seats</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>accessories, car, seats</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>nursery, closet, dividers</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>changing, dressing, nursery</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>holders, diapering, wipes</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>nasal, care, health</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>breastfeeding, nursing, feeding</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>accessories, seat, strollers</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>accessories, seat, car</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>feeding, solid, dishes</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>cereal, feeding, foods</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>blankets, nursery, bedding</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>hair, care, ties</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>wipes, refills, diapering</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>care, grooming, skin</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>burp, cloths, feeding</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>accessories, strollers, stroller</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>accessories, insect, netting</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>training, potty, pants</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>locks, safety, cabinet</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>storage, nursery, furniture</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>toddler, nursery, furniture</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>bathing, skin, care</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>nursery, trend, spruce</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>gyms, playmats, activity</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>swings, activity, entertainment</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>bedding, sets, crib</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>care, grooming, skin</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>blankets, swaddling, nursery</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>diaper, bags, disposal</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>diapering, disposable, diapers</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>gates, gate, safety</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>highchairs, feeding, booster</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>feeding, solid, dishes</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>accessories, car, head</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>strollers, tandem, accessories</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>feeding, bottle, hands</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>washcloths, care, bathing</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>feeding, breastfeeding, nursing</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>towels, care, bathing</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>wall, nursery, plaques</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>gift, baskets, gifts</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>bedding, pillowcases, nursery</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>accessories, strollers, travel</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>monitors, safety, smart</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>blankets, nursery, bedding</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>liners, nursery, baskets</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>diaper, bags, diapering</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>feeding, solid, place</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>bedding, nursery, accessories</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>gift, sets, gifts</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>nursery, wall, growth</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>pacifier, care, pacifiers</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>teethers, care, pacifiers</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>feeding, food, storage</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>accessories, car, seats</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>feeding, nipples, bottle</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>care, health, colic</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>feeding, solid, dishes</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>pillow, covers, feeding</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>bibs, feeding, burp</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>diaper, diapering, bags</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>redeem, nursery, event</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>nursery, furniture, toddler</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>potty, training, potties</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>potty, training, travel</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>accessories, car, seats</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>strollers, lightweight, accessories</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>bibs, feeding, burp</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>accessories, car, rear</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>corner, guards, edge</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>care, grooming, skin</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>cloth, diapers, diapering</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>pacifiers, care, teethers</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>accessories, car, seats</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>breast, pump, breastfeeding</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>safety, monitors, snuza</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>blankets, nursery, bedding</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>breast, electric, feeding</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>cloth, inserts, diapers</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>safety, care, grooming</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>feeding, bottle, bottles</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>keepsakes, gifts, furniture</td>
#     </tr>
#     <tr>
# <style>
# .scrollable-table {
#     display: block;
#     max-height: 400px;
#     overflow-y: auto;
#     border: 1px solid #ccc;
#     padding: 10px;
# }
# </style>

# %% [markdown]
# Now use TF-IDF.

# %%
# Identify the most frequently used words from each cluster
top_words_dict_tfidf = get_tfidf_top_words(hdb_scan, 'cluster', 'tokens', top_n=3)

# SMerge tfidf top words back onto your original dataframe by cluster
hdb_scan = hdb_scan.merge(top_words_dict_tfidf, on = 'cluster', how = 'left')

# Svae top_words_tfidf as a readable string
hdb_scan['top_words_tfidf'] = hdb_scan['top_words_tfidf'].apply(
    lambda words: ', '.join(words) if isinstance(words, list) else ''
)

# %%
# Print out the top 3 words for each cluster

# Keep only necessary columns
df_cluster_words_hdbscan_tfidf = hdb_scan[['cluster', 'top_words_tfidf']].copy()

# Convert top words to a tuple and only get unique instances of clusters and top words
df_cluster_words_hdbscan_tfidf['top_words_tuple'] = df_cluster_words_hdbscan_tfidf['top_words_tfidf'].apply(lambda x: tuple(x))
df_cluster_words_hdbscan_tfidf = df_cluster_words_hdbscan_tfidf.drop_duplicates(subset=['cluster', 'top_words_tuple'])

# Drop the tuple column
df_cluster_words_hdbscan_tfidf = df_cluster_words_hdbscan_tfidf.drop(columns='top_words_tuple')

# Sort by cluster
df_cluster_words_hdbscan_tfidf = df_cluster_words_hdbscan_tfidf.sort_values(by='cluster').reset_index(drop=True)

display(HTML(df_cluster_words_hdbscan_tfidf.to_html(
    max_rows=300, notebook=True, index=False, justify='center',
    classes='scrollable-table', escape=False, table_id='cluster_table'
)))

# Inject some CSS to enable scrollable output
display(HTML('''
<style>
.scrollable-table {
    display: block;
    max-height: 400px;
    overflow-y: auto;
    border: 1px solid #ccc;
    padding: 10px;
}
</style>
'''))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe scrollable-table" id="cluster_table">
#   <thead>
#     <tr style="text-align: center;">
#       <th>cluster</th>
#       <th>top_words_tfidf</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-1</td>
#       <td>bedding, accessories, nursery</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>bedding, swaddling, nursery</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sheets, bedding, nursery</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>hair, care, clips</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>storage, stools, step</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>makers, keepsakes, hand</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>bedding, sets, nursery</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>accessories, strollers, hooks</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>playards, furniture, nursery</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>accessories, strollers, connectors</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>stackers, diapering, caddies</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>accessories, travel, gear</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>accessories, covers, diapering</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>organizers, furniture, storage</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>wall, nursery, numbers</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>accessories, seats, car</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>accessories, seats, covers</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>nursery, organizer, koala</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>changing, furniture, nursery</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>holders, wipes, wipe</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>aspirators, care, health</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>feeding, covers, nursing</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>accessories, strollers, liners</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>accessories, automotive, seats</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>feeding, solid, plates</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>cereal, straps, safety</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>bedding, quilts, swaddling</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>care, hair, accessories</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>wipes, diapering, holders</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>care, skin, oils</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>cloths, burp, feeding</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>accessories, strollers, stroller</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>accessories, strollers, insect</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>training, pants, potty</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>locks, guards, cabinet</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>storage, bins, organization</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>nursery, furniture, beds</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>skin, care, bathing</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>nursery, trend, lab</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>entertainment, activity, playmats</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>swings, entertainment, bouncers</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>bedding, sets, nursery</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>care, skin, grooming</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>swaddling, blankets, nursery</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>diaper, diapering, pails</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>diapers, disposable, diapering</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>gates, extensions, stair</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>highchairs, seats, feeding</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>feeding, solid, dishes</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>accessories, supports, seats</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>strollers, accessories, tandem</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>feeding, bottle, hands</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>washcloths, wash, towels</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>pads, nursing, breastfeeding</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>towels, washcloths, hooded</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>wall, plaques, nursery</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>gifts, baskets, gift</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>pillowcases, bedding, toddler</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>accessories, travel, strollers</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>monitors, smart, safety</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>blankets, swaddling, receiving</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>nursery, baskets, liners</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>diapering, diaper, bags</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>feeding, solid, place</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>bedding, protection, nursery</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>gifts, sets, gift</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>wall, nursery, growth</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>accessories, teethers, relief</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>teethers, teething, relief</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>storage, food, feeding</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>accessories, storage, seats</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>feeding, bottle, nipples</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>relief, health, gas</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>feeding, solid, dishes</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>covers, pillow, pillows</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>bibs, feeding, burp</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>totes, diapering, bags</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>shipping, sent, code</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>toddler, nursery, furniture</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>potties, training, potty</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>travel, training, potty</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>accessories, seats, seat</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>strollers, accessories, lightweight</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>bibs, feeding, cloths</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>accessories, mirrors, seats</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>edge, safety, guards</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>care, skin, powders</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>diapers, cloth, diapering</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>pacifiers, teething, teethers</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>accessories, travel, seats</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>feeding, accessories, breastfeeding</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>safety, monitors, snuza</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>blankets, wearable, swaddling</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>pumps, breastfeeding, feeding</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>accessories, diapering, diapers</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>safety, care, skin</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>feeding, bottles, bottle</td>
#     </tr>
#     <tr>
# <style>
# .scrollable-table {
#     display: block;
#     max-height: 400px;
#     overflow-y: auto;
#     border: 1px solid #ccc;
#     padding: 10px;
# }
# </style>

# %% [markdown]
# ## Identify "Outcasts"
#
# Identify descriptions in each cluster that do not have obne of the top 3 most used words in their description.

# %%
# Create a function which flags records that do not have one of the top 3 words in their description
def lacks_top_words(row):
    # Ensure tokens is a list
    if not isinstance(row['tokens'], list):
        return True

    # Convert top_words and tfidf to lists if they are comma-separated strings
    top_words = row['top_words']
    tfidf_words = row['top_words_tfidf']

    if isinstance(top_words, str):
        top_words = [w.strip() for w in top_words.split(',')]
    if isinstance(tfidf_words, str):
        tfidf_words = [w.strip() for w in tfidf_words.split(',')]

    # Check if any top word or tfidf word appears in tokens
    return not any(word in row['tokens'] for word in top_words) and \
           not any(word in row['tokens'] for word in tfidf_words)

# %% [markdown]
# ### K-Means: 19
#
# Check the number of records which do not have a description with one of the top words from either the top words or TF-IDF top words check.

# %%
# Identify records in the kmeans_19 dataframe with descriptions lacking the top words of their respective cluster
# Apply the function to flag rows missing top words
kmeans_19['missing_top_word'] = kmeans_19.apply(lacks_top_words, axis=1)

# %%
# Get a sense of how many observations have the top words and how many do not
grouped_counts_19 = (
    kmeans_19
    .groupby(['cluster', 'top_words', 'top_words_tfidf', 'missing_top_word'])
    .size()
    .reset_index(name='count')
)

# Order by cluster
grouped_counts_19 = grouped_counts_19.sort_values(by = ['cluster', 'missing_top_word']).reset_index(drop = True)

# View the result
grouped_counts_19.head(100)
# Out:
#     cluster                         top_words  \
# 0         0           accessories, car, seats
# 1         0           accessories, car, seats
# 2         1     activity, entertainment, gyms
# 3         1     activity, entertainment, gyms
# 4         2      blankets, swaddling, nursery
# 5         2      blankets, swaddling, nursery
# 6         3           nursery, wall, stickers
# 7         3           nursery, wall, stickers
# 8         4           care, hair, accessories
# 9         4           care, hair, accessories
# 10        5              feeding, solid, cups
# 11        5              feeding, solid, cups
# 12        6           diaper, bags, diapering
# 13        6           diaper, bags, diapering
# 14        7         diapering, diapers, cloth
# 15        7         diapering, diapers, cloth
# 16        8               bibs, feeding, burp
# 17        8               bibs, feeding, burp
# 18        9            training, potty, pants
# 19       10          bedding, nursery, sheets
# 20       10          bedding, nursery, sheets
# 21       11          feeding, bottle, bottles
# 22       12    feeding, breastfeeding, breast
# 23       12    feeding, breastfeeding, breast
# 24       13       nursery, furniture, storage
# 25       13       nursery, furniture, storage
# 26       14             safety, guards, locks
# 27       14             safety, guards, locks
# 28       15  accessories, strollers, standard
# 29       15  accessories, strollers, standard
# 30       16             care, bathing, towels
# 31       16             care, bathing, towels
# 32       17     teethers, pacifiers, teething
# 33       18                 gifts, gift, sets
# 34       18                 gifts, gift, sets
#
#                      top_words_tfidf  missing_top_word  count
# 0            accessories, seats, car             False   8731
# 1            accessories, seats, car              True      6
# 2      activity, entertainment, gyms             False   4014
# 3      activity, entertainment, gyms              True      9
# 4       blankets, swaddling, bedding             False  18377
# 5       blankets, swaddling, bedding              True     25
# 6            wall, stickers, nursery             False  21392
# 7            wall, stickers, nursery              True     21
# 8            hair, care, accessories             False   7105
# 9            hair, care, accessories              True      3
# 10              feeding, solid, cups             False  14475
# 11              feeding, solid, cups              True      6
# 12           diapering, bags, diaper             False   7821
# 13           diapering, bags, diaper              True      1
# 14         diapering, diapers, cloth             False  17843
# 15         diapering, diapers, cloth              True    673
# 16         bibs, feeding, highchairs             False   6109
# 17         bibs, feeding, highchairs              True  14509
# 18            training, potty, pants             False   4672
# 19          bedding, sheets, nursery             False  14378
# 20          bedding, sheets, nursery              True    362
# 21          feeding, bottle, bottles             False   5781
# 22    breastfeeding, feeding, breast             False   4977
# 23    breastfeeding, feeding, breast              True    607
# 24       nursery, storage, furniture             False  19958
# 25       nursery, storage, furniture              True     46
# 26             safety, locks, guards             False  14229
# 27             safety, locks, guards              True     42
# 28  strollers, accessories, standard             False  10694
# 29  strollers, accessories, standard              True    366
# 30             care, towels, bathing             False   8878
# 31             care, towels, bathing              True     86
# 32     teethers, pacifiers, teething             False   4686
# 33                 gifts, gift, sets             False   6545
# 34                 gifts, gift, sets              True    297

# %%
# Count the number of "True" records in this dataframe
kmeans_19.missing_top_word.value_counts()
# Out:
# missing_top_word
# False    200665
# True      17059
# Name: count, dtype: int64

# %%
# Percentage of cases missing one of the top words
counts = kmeans_19['missing_top_word'].value_counts()
percent_true = (counts.get(True, 0) / counts.sum()) * 100
percent_false = (counts.get(False, 0) / counts.sum()) * 100
print(f"Records WITHOUT the Top Words in their Description - {percent_true:.2f}%")
print(f"Records WITH the Top Words in their Description - {percent_false:.2f}%")
# Out:
# Records WITHOUT the Top Words in their Description - 7.84%
# Records WITH the Top Words in their Description - 92.16%

# %% [markdown]
# ### K-Means: 42
#
# Identify the number of records without any of the top words in their descriptions for the K-Means 42 cluster dataset.

# %%
# Identify records in the kmeans_42 dataframe with descriptions lacking the top words of their respective cluster
# Apply the function to flag rows missing top words
kmeans_42['missing_top_word'] = kmeans_42.apply(lacks_top_words, axis=1)

# %%
# Get a sense of how many observations have the top words and how many do not
grouped_counts_42 = (
    kmeans_42
    .groupby(['cluster', 'top_words', 'top_words_tfidf', 'missing_top_word'])
    .size()
    .reset_index(name='count')
)

# Order by cluster
grouped_counts_42 = grouped_counts_42.sort_values(by = ['cluster', 'missing_top_word']).reset_index(drop = True)

# View the result
display(HTML(grouped_counts_42.to_html(
    max_rows=300, notebook=True, index=False, justify='center',
    classes='scrollable-table', escape=False, table_id='cluster_table'
)))

# Inject some CSS to enable scrollable output
display(HTML('''
<style>
.scrollable-table {
    display: block;
    max-height: 400px;
    overflow-y: auto;
    border: 1px solid #ccc;
    padding: 10px;
}
</style>
'''))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe scrollable-table" id="cluster_table">
#   <thead>
#     <tr style="text-align: center;">
#       <th>cluster</th>
#       <th>top_words</th>
#       <th>top_words_tfidf</th>
#       <th>missing_top_word</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>cloth, diapers, diapering</td>
#       <td>diapers, cloth, covers</td>
#       <td>False</td>
#       <td>6457</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>cloth, diapers, diapering</td>
#       <td>diapers, cloth, covers</td>
#       <td>True</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>storage, furniture, nursery</td>
#       <td>storage, organization, furniture</td>
#       <td>False</td>
#       <td>9510</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>storage, furniture, nursery</td>
#       <td>storage, organization, furniture</td>
#       <td>True</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>blankets, swaddling, nursery</td>
#       <td>blankets, swaddling, bedding</td>
#       <td>False</td>
#       <td>18371</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>blankets, swaddling, nursery</td>
#       <td>blankets, swaddling, bedding</td>
#       <td>True</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>feeding, solid, cups</td>
#       <td>feeding, cups, solid</td>
#       <td>False</td>
#       <td>9013</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>feeding, solid, cups</td>
#       <td>feeding, cups, solid</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>pillows, nursery, maternity</td>
#       <td>pillows, nursery, maternity</td>
#       <td>False</td>
#       <td>2687</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>pillows, nursery, maternity</td>
#       <td>pillows, nursery, maternity</td>
#       <td>True</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>wall, stickers, nursery</td>
#       <td>nursery, stickers, wall</td>
#       <td>False</td>
#       <td>14388</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>wall, stickers, nursery</td>
#       <td>nursery, stickers, wall</td>
#       <td>True</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>care, hair, accessories</td>
#       <td>care, hair, accessories</td>
#       <td>False</td>
#       <td>5672</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>gates, gate, safety</td>
#       <td>gates, extensions, stair</td>
#       <td>False</td>
#       <td>2296</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>strollers, accessories, standard</td>
#       <td>strollers, accessories, standard</td>
#       <td>False</td>
#       <td>4834</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>strollers, accessories, standard</td>
#       <td>strollers, accessories, standard</td>
#       <td>True</td>
#       <td>104</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>care, health, kids</td>
#       <td>care, health, thermometers</td>
#       <td>False</td>
#       <td>2651</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>care, health, kids</td>
#       <td>care, health, thermometers</td>
#       <td>True</td>
#       <td>10053</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>gifts, gift, sets</td>
#       <td>gift, gifts, sets</td>
#       <td>False</td>
#       <td>6457</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>gifts, gift, sets</td>
#       <td>gift, gifts, sets</td>
#       <td>True</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>bedding, nursery, sets</td>
#       <td>bedding, sets, nursery</td>
#       <td>False</td>
#       <td>6040</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>bedding, nursery, sets</td>
#       <td>bedding, sets, nursery</td>
#       <td>True</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>training, potty, pants</td>
#       <td>training, potty, pants</td>
#       <td>False</td>
#       <td>4659</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>accessories, car, seats</td>
#       <td>accessories, seats, car</td>
#       <td>False</td>
#       <td>8700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>accessories, car, seats</td>
#       <td>accessories, seats, car</td>
#       <td>True</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>feeding, bottle, bottles</td>
#       <td>feeding, bottle, bottles</td>
#       <td>False</td>
#       <td>5773</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>feeding, bottle, bottles</td>
#       <td>feeding, bottle, bottles</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>care, grooming, skin</td>
#       <td>care, grooming, skin</td>
#       <td>False</td>
#       <td>4773</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>care, grooming, skin</td>
#       <td>care, grooming, skin</td>
#       <td>True</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>diapering, wipes, holders</td>
#       <td>diapering, disposable, diapers</td>
#       <td>False</td>
#       <td>6801</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>diapering, wipes, holders</td>
#       <td>diapering, disposable, diapers</td>
#       <td>True</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>safety, leashes, harnesses</td>
#       <td>safety, bathroom, harnesses</td>
#       <td>False</td>
#       <td>4110</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>safety, leashes, harnesses</td>
#       <td>safety, bathroom, harnesses</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>bathing, care, soaps</td>
#       <td>bathing, care, soaps</td>
#       <td>False</td>
#       <td>2329</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>bathing, care, soaps</td>
#       <td>bathing, care, soaps</td>
#       <td>True</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>teethers, pacifiers, teething</td>
#       <td>teethers, pacifiers, teething</td>
#       <td>False</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>locks, safety, guards</td>
#       <td>locks, guards, safety</td>
#       <td>False</td>
#       <td>3462</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>locks, safety, guards</td>
#       <td>locks, guards, safety</td>
#       <td>True</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>bibs, burp, cloths</td>
#       <td>bibs, cloths, burp</td>
#       <td>False</td>
#       <td>3279</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>diaper, bags, diapering</td>
#       <td>totes, diapering, bags</td>
#       <td>False</td>
#       <td>6462</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>nursery, wall, furniture</td>
#       <td>nursery, wall, mobiles</td>
#       <td>False</td>
#       <td>12547</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>nursery, wall, furniture</td>
#       <td>nursery, wall, mobiles</td>
#       <td>True</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>bedding, sheets, nursery</td>
#       <td>sheets, bedding, nursery</td>
#       <td>False</td>
#       <td>5738</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>bedding, sheets, nursery</td>
#       <td>sheets, bedding, nursery</td>
#       <td>True</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>breastfeeding, feeding, nursing</td>
#       <td>feeding, breastfeeding, nursing</td>
#       <td>False</td>
#       <td>1927</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>breastfeeding, feeding, nursing</td>
#       <td>feeding, breastfeeding, nursing</td>
#       <td>True</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>highchairs, booster, seats</td>
#       <td>highchairs, seats, booster</td>
#       <td>False</td>
#       <td>2527</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>highchairs, booster, seats</td>
#       <td>highchairs, seats, booster</td>
#       <td>True</td>
# <style>
# .scrollable-table {
#     display: block;
#     max-height: 400px;
#     overflow-y: auto;
#     border: 1px solid #ccc;
#     padding: 10px;
# }
# </style>

# %%
# Count the number of "True" records in this dataframe
kmeans_42.missing_top_word.value_counts()
# Out:
# missing_top_word
# False    207246
# True      10478
# Name: count, dtype: int64

# %%
# Percentage of cases missing one of the top words
counts = kmeans_42['missing_top_word'].value_counts()
percent_true = (counts.get(True, 0) / counts.sum()) * 100
percent_false = (counts.get(False, 0) / counts.sum()) * 100
print(f"Records WITHOUT the Top Words in their Description - {percent_true:.2f}%")
print(f"Records WITH the Top Words in their Description - {percent_false:.2f}%")
# Out:
# Records WITHOUT the Top Words in their Description - 4.81%
# Records WITH the Top Words in their Description - 95.19%

# %% [markdown]
# ### HDBSCAN: 235
#
# Finally, go ahead and perform the same analysis with the HDBSCAN Clusters.

# %%
# Identify records in the hdb_scan dataframe with descriptions lacking the top words of their respective cluster
# Apply the function to flag rows missing top words
hdb_scan['missing_top_word'] = hdb_scan.apply(lacks_top_words, axis=1)

# %%
# Get a sense of how many observations have the top words and how many do not
grouped_counts_hdbscan = (
    hdb_scan
    .groupby(['cluster', 'top_words', 'top_words_tfidf', 'missing_top_word'])
    .size()
    .reset_index(name='count')
)

# Order by cluster
grouped_counts_hdbscan = grouped_counts_hdbscan.sort_values(by = ['cluster', 'missing_top_word']).reset_index(drop = True)

# View the result
display(HTML(grouped_counts_hdbscan.to_html(
    max_rows=8000, notebook=True, index=False, justify='center',
    classes='scrollable-table', escape=False, table_id='cluster_table'
)))

# Inject some CSS to enable scrollable output
display(HTML('''
<style>
.scrollable-table {
    display: block;
    max-height: 400px;
    overflow-y: auto;
    border: 1px solid #ccc;
    padding: 10px;
}
</style>
'''))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe scrollable-table" id="cluster_table">
#   <thead>
#     <tr style="text-align: center;">
#       <th>cluster</th>
#       <th>top_words</th>
#       <th>top_words_tfidf</th>
#       <th>missing_top_word</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-1</td>
#       <td>bedding, nursery, accessories</td>
#       <td>bedding, accessories, nursery</td>
#       <td>False</td>
#       <td>3569</td>
#     </tr>
#     <tr>
#       <td>-1</td>
#       <td>bedding, nursery, accessories</td>
#       <td>bedding, accessories, nursery</td>
#       <td>True</td>
#       <td>8433</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>nursery, blankets, swaddling</td>
#       <td>bedding, swaddling, nursery</td>
#       <td>False</td>
#       <td>2555</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>bedding, sheets, crib</td>
#       <td>sheets, bedding, nursery</td>
#       <td>False</td>
#       <td>3490</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>care, hair, accessories</td>
#       <td>hair, care, clips</td>
#       <td>False</td>
#       <td>1186</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nursery, furniture, storage</td>
#       <td>storage, stools, step</td>
#       <td>False</td>
#       <td>997</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>gifts, keepsakes, hand</td>
#       <td>makers, keepsakes, hand</td>
#       <td>False</td>
#       <td>405</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>bedding, toddler, nursery</td>
#       <td>bedding, sets, nursery</td>
#       <td>False</td>
#       <td>836</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>accessories, stroller, strollers</td>
#       <td>accessories, strollers, hooks</td>
#       <td>False</td>
#       <td>464</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nursery, furniture, playards</td>
#       <td>playards, furniture, nursery</td>
#       <td>False</td>
#       <td>1140</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nursery, furniture, playards</td>
#       <td>playards, furniture, nursery</td>
#       <td>True</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>accessories, stroller, strollers</td>
#       <td>accessories, strollers, connectors</td>
#       <td>False</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>accessories, stroller, strollers</td>
#       <td>accessories, strollers, connectors</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>diaper, diapering, stackers</td>
#       <td>stackers, diapering, caddies</td>
#       <td>False</td>
#       <td>1285</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>accessories, travel, gear</td>
#       <td>accessories, travel, gear</td>
#       <td>False</td>
#       <td>203</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>cloth, diapering, diapers</td>
#       <td>accessories, covers, diapering</td>
#       <td>False</td>
#       <td>3662</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>hanging, nursery, storage</td>
#       <td>organizers, furniture, storage</td>
#       <td>False</td>
#       <td>1515</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>nursery, wall, letters</td>
#       <td>wall, nursery, numbers</td>
#       <td>False</td>
#       <td>170</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>accessories, car, seats</td>
#       <td>accessories, seats, car</td>
#       <td>False</td>
#       <td>571</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>accessories, car, seats</td>
#       <td>accessories, seats, covers</td>
#       <td>False</td>
#       <td>1189</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>nursery, closet, dividers</td>
#       <td>nursery, organizer, koala</td>
#       <td>False</td>
#       <td>479</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>nursery, closet, dividers</td>
#       <td>nursery, organizer, koala</td>
#       <td>True</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>changing, dressing, nursery</td>
#       <td>changing, furniture, nursery</td>
#       <td>False</td>
#       <td>643</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>changing, dressing, nursery</td>
#       <td>changing, furniture, nursery</td>
#       <td>True</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>holders, diapering, wipes</td>
#       <td>holders, wipes, wipe</td>
#       <td>False</td>
#       <td>669</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>nasal, care, health</td>
#       <td>aspirators, care, health</td>
#       <td>False</td>
#       <td>492</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>breastfeeding, nursing, feeding</td>
#       <td>feeding, covers, nursing</td>
#       <td>False</td>
#       <td>696</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>accessories, seat, strollers</td>
#       <td>accessories, strollers, liners</td>
#       <td>False</td>
#       <td>347</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>accessories, seat, car</td>
#       <td>accessories, automotive, seats</td>
#       <td>False</td>
#       <td>560</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>feeding, solid, dishes</td>
#       <td>feeding, solid, plates</td>
#       <td>False</td>
#       <td>744</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>feeding, solid, dishes</td>
#       <td>feeding, solid, plates</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>cereal, feeding, foods</td>
#       <td>cereal, straps, safety</td>
#       <td>False</td>
#       <td>297</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>blankets, nursery, bedding</td>
#       <td>bedding, quilts, swaddling</td>
#       <td>False</td>
#       <td>242</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>blankets, nursery, bedding</td>
#       <td>bedding, quilts, swaddling</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>hair, care, ties</td>
#       <td>care, hair, accessories</td>
#       <td>False</td>
#       <td>233</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>wipes, refills, diapering</td>
#       <td>wipes, diapering, holders</td>
#       <td>False</td>
#       <td>1200</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>wipes, refills, diapering</td>
#       <td>wipes, diapering, holders</td>
#       <td>True</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>care, grooming, skin</td>
#       <td>care, skin, oils</td>
#       <td>False</td>
#       <td>353</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>burp, cloths, feeding</td>
#       <td>cloths, burp, feeding</td>
#       <td>False</td>
#       <td>823</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>accessories, strollers, stroller</td>
#       <td>accessories, strollers, stroller</td>
#       <td>False</td>
#       <td>373</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>accessories, insect, netting</td>
#       <td>accessories, strollers, insect</td>
#       <td>False</td>
#       <td>216</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>training, potty, pants</td>
#       <td>training, pants, potty</td>
#       <td>False</td>
#       <td>1729</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>locks, safety, cabinet</td>
#       <td>locks, guards, cabinet</td>
#       <td>False</td>
#       <td>1747</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>storage, nursery, furniture</td>
#       <td>storage, bins, organization</td>
#       <td>False</td>
#       <td>4114</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>toddler, nursery, furniture</td>
#       <td>nursery, furniture, beds</td>
#       <td>False</td>
#       <td>226</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>bathing, skin, care</td>
#       <td>skin, care, bathing</td>
#       <td>False</td>
#       <td>506</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>bathing, skin, care</td>
#       <td>skin, care, bathing</td>
#       <td>True</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>3
# <style>
# .scrollable-table {
#     display: block;
#     max-height: 400px;
#     overflow-y: auto;
#     border: 1px solid #ccc;
#     padding: 10px;
# }
# </style>

# %%
# Count the number of "True" records in this dataframe
hdb_scan.missing_top_word.value_counts()
# Out:
# missing_top_word
# False    206573
# True      11151
# Name: count, dtype: int64

# %%
# Percentage of cases missing one of the top words
counts = hdb_scan['missing_top_word'].value_counts()
percent_true = (counts.get(True, 0) / counts.sum()) * 100
percent_false = (counts.get(False, 0) / counts.sum()) * 100
print(f"Records WITHOUT the Top Words in their Description - {percent_true:.2f}%")
print(f"Records WITH the Top Words in their Description - {percent_false:.2f}%")
# Out:
# Records WITHOUT the Top Words in their Description - 5.12%
# Records WITH the Top Words in their Description - 94.88%

# %% [markdown]
# ### Save Non-Matches
# Create dataframes of just the records whose descriptions do not match the top words.

# %%
# Save dataframes
kmeans_19_nonmatching = kmeans_19[kmeans_19['missing_top_word'] == True]
kmeans_42_nonmatching = kmeans_42[kmeans_42['missing_top_word'] == True]
hdb_scan_nonmatching = hdb_scan[hdb_scan['missing_top_word'] == True]

# %% [markdown]
# ## Output to Excel
#
# Output the results produced above to Excel. Specifically, focus on the datasets with the number of top words and the breakdown of True and False by topword. Also get the datasets of records without the top words in their descriptions.

# %%
# K-Means 19 Datasets
with pd.ExcelWriter('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/kmeans-19-breakdown.xlsx', engine='openpyxl') as writer:
    kmeans_19_nonmatching.to_excel(writer, sheet_name='cluster_19_nonmatching', index=False)
    grouped_counts_19.to_excel(writer, sheet_name='cluster_19_counts', index=False)
    df_cluster_words_19.to_excel(writer, sheet_name='cluster-by-freq')
    df_cluster_words_19_tfidf.to_excel(writer, sheet_name='cluster-tfidf')

# K-Means 42 Datasets
with pd.ExcelWriter('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/kmeans-42-breakdown.xlsx', engine='openpyxl') as writer:
    kmeans_42_nonmatching.to_excel(writer, sheet_name='cluster_42_nonmatching', index=False)
    grouped_counts_42.to_excel(writer, sheet_name='cluster_42_counts', index=False)
    df_cluster_words_42.to_excel(writer, sheet_name='cluster-by-freq')
    df_cluster_words_42_tfidf.to_excel(writer, sheet_name='cluster-tfidf')

# HDBSCAN Datasets
with pd.ExcelWriter('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/hdbscan-breakdown.xlsx', engine='openpyxl') as writer:
    hdb_scan_nonmatching.to_excel(writer, sheet_name='cluster_hdbscan_nonmatching', index=False)
    grouped_counts_hdbscan.to_excel(writer, sheet_name='cluster_hdbscan_counts', index=False)
    df_cluster_words_hdbscan.to_excel(writer, sheet_name='cluster-by-freq')
    df_cluster_words_hdbscan_tfidf.to_excel(writer, sheet_name='cluster-tfidf')

# %% [markdown]
# Use the above created Excel documents to perform hands-on exploratory analysis with the data. Once completed, come back to the code and identify ways to break down the clusters in more detail.

# %% [markdown]
# ## Further Cluster Analysis
#
# After exploring the data independently, it seems like we will want to explore the HDBSCAN Cluster results. While we will attempt to shrink the number of categories accordingly, the results from K-Means = 19 do not appear as useful, due to the poor performance of Cluster 8, which captures a large amount of categories ranging from strollers, to bibs, to high chairs, etc.
#
# K-Means 42 also appears to have its difficulties. Cluster 9 also appears to havepoor performance with a large number of records no matching any of the top words. With that said, HDBSCAN contains way too many clusters to use in a dashboard, so the goal will be to ultimately reduce the number of clusters overall. We could use the K-Means 42 results, but HDBSCAN proves to work better with BERT models and may still not provide the proper distinction between clusters that HDBSCAN does (may be easier to work down from too many clusters as opposed to beginning with a smaller amount).
#
# We will start by looking at the HDBSCAN results, see how many meaningful clusters we cna reduce it to by grouping several clusters together.

# %% [markdown]
# ### HDBSCAN Breakdown - Reduce into Meaningful Clusters

# %%
# Create a dataset with just the top words (both tf-idf and just by freq)
hdb_cluster_additional_analysis = df_cluster_words_hdbscan.merge(df_cluster_words_hdbscan_tfidf, left_on='cluster', right_on='cluster')

# Combine all top words together into one string
hdb_cluster_additional_analysis['top_words'] = hdb_cluster_additional_analysis['top_words'].apply(
    lambda x: ' '.join(x.split(', '))
)

hdb_cluster_additional_analysis['top_words_tfidf'] = hdb_cluster_additional_analysis['top_words_tfidf'].apply(
    lambda x: ' '.join(x.split(', '))
)

hdb_cluster_additional_analysis['top_words_combined'] = (
    hdb_cluster_additional_analysis['top_words'] + ' ' + hdb_cluster_additional_analysis['top_words_tfidf']
)

# Vectorize the cluster labels
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(hdb_cluster_additional_analysis['top_words_combined'])

# Measure the similarity across clusters
similarity_matrix = cosine_similarity(X)

# Group similar clusters
n_final_groups = 60  # tweak this
cluster_grouper = AgglomerativeClustering(n_clusters=n_final_groups, metric='precomputed', linkage='average')
group_assignments = cluster_grouper.fit_predict(1 - similarity_matrix)

hdb_cluster_additional_analysis['merged_cluster'] = group_assignments

# View the result
display(HTML(hdb_cluster_additional_analysis.to_html(
    max_rows=300, notebook=True, index=False, justify='center',
    classes='scrollable-table', escape=False, table_id='cluster_table'
)))

# Inject some CSS to enable scrollable output
display(HTML('''
<style>
.scrollable-table {
    display: block;
    max-height: 400px;
    overflow-y: auto;
    border: 1px solid #ccc;
    padding: 10px;
}
</style>
'''))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe scrollable-table" id="cluster_table">
#   <thead>
#     <tr style="text-align: center;">
#       <th>cluster</th>
#       <th>top_words</th>
#       <th>top_words_tfidf</th>
#       <th>top_words_combined</th>
#       <th>merged_cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-1</td>
#       <td>bedding nursery accessories</td>
#       <td>bedding accessories nursery</td>
#       <td>bedding nursery accessories bedding accessories...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>nursery blankets swaddling</td>
#       <td>bedding swaddling nursery</td>
#       <td>nursery blankets swaddling bedding swaddling nu...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>bedding sheets crib</td>
#       <td>sheets bedding nursery</td>
#       <td>bedding sheets crib sheets bedding nursery</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>care hair accessories</td>
#       <td>hair care clips</td>
#       <td>care hair accessories hair care clips</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nursery furniture storage</td>
#       <td>storage stools step</td>
#       <td>nursery furniture storage storage stools step</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>gifts keepsakes hand</td>
#       <td>makers keepsakes hand</td>
#       <td>gifts keepsakes hand makers keepsakes hand</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>bedding toddler nursery</td>
#       <td>bedding sets nursery</td>
#       <td>bedding toddler nursery bedding sets nursery</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>accessories stroller strollers</td>
#       <td>accessories strollers hooks</td>
#       <td>accessories stroller strollers accessories stro...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nursery furniture playards</td>
#       <td>playards furniture nursery</td>
#       <td>nursery furniture playards playards furniture n...</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>accessories stroller strollers</td>
#       <td>accessories strollers connectors</td>
#       <td>accessories stroller strollers accessories stro...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>diaper diapering stackers</td>
#       <td>stackers diapering caddies</td>
#       <td>diaper diapering stackers stackers diapering ca...</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>accessories travel gear</td>
#       <td>accessories travel gear</td>
#       <td>accessories travel gear accessories travel gear</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>cloth diapering diapers</td>
#       <td>accessories covers diapering</td>
#       <td>cloth diapering diapers accessories covers diap...</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>hanging nursery storage</td>
#       <td>organizers furniture storage</td>
#       <td>hanging nursery storage organizers furniture st...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>nursery wall letters</td>
#       <td>wall nursery numbers</td>
#       <td>nursery wall letters wall nursery numbers</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>accessories car seats</td>
#       <td>accessories seats car</td>
#       <td>accessories car seats accessories seats car</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>accessories car seats</td>
#       <td>accessories seats covers</td>
#       <td>accessories car seats accessories seats covers</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>nursery closet dividers</td>
#       <td>nursery organizer koala</td>
#       <td>nursery closet dividers nursery organizer koala</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>changing dressing nursery</td>
#       <td>changing furniture nursery</td>
#       <td>changing dressing nursery changing furniture nu...</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>holders diapering wipes</td>
#       <td>holders wipes wipe</td>
#       <td>holders diapering wipes holders wipes wipe</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>nasal care health</td>
#       <td>aspirators care health</td>
#       <td>nasal care health aspirators care health</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>breastfeeding nursing feeding</td>
#       <td>feeding covers nursing</td>
#       <td>breastfeeding nursing feeding feeding covers nu...</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>accessories seat strollers</td>
#       <td>accessories strollers liners</td>
#       <td>accessories seat strollers accessories stroller...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>accessories seat car</td>
#       <td>accessories automotive seats</td>
#       <td>accessories seat car accessories automotive seats</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>feeding solid dishes</td>
#       <td>feeding solid plates</td>
#       <td>feeding solid dishes feeding solid plates</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>cereal feeding foods</td>
#       <td>cereal straps safety</td>
#       <td>cereal feeding foods cereal straps safety</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>blankets nursery bedding</td>
#       <td>bedding quilts swaddling</td>
#       <td>blankets nursery bedding bedding quilts swaddling</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>hair care ties</td>
#       <td>care hair accessories</td>
#       <td>hair care ties care hair accessories</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>wipes refills diapering</td>
#       <td>wipes diapering holders</td>
#       <td>wipes refills diapering wipes diapering holders</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>care grooming skin</td>
#       <td>care skin oils</td>
#       <td>care grooming skin care skin oils</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>burp cloths feeding</td>
#       <td>cloths burp feeding</td>
#       <td>burp cloths feeding cloths burp feeding</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>accessories strollers stroller</td>
#       <td>accessories strollers stroller</td>
#       <td>accessories strollers stroller accessories stro...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>accessories insect netting</td>
#       <td>accessories strollers insect</td>
#       <td>accessories insect netting accessories stroller...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>training potty pants</td>
#       <td>training pants potty</td>
#       <td>training potty pants training pants potty</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>locks safety cabinet</td>
#       <td>locks guards cabinet</td>
#       <td>locks safety cabinet locks guards cabinet</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>storage nursery furniture</td>
#       <td>storage bins organization</td>
#       <td>storage nursery furniture storage bins organiza...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>toddler nursery furniture</td>
#       <td>nursery furniture beds</td>
#       <td>toddler nursery furniture nursery furniture beds</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>bathing skin care</td>
#       <td>skin care bathing</td>
#       <td>bathing skin care skin care bathing</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>nursery trend spruce</td>
#       <td>nursery trend lab</td>
#       <td>nursery trend spruce n
# <style>
# .scrollable-table {
#     display: block;
#     max-height: 400px;
#     overflow-y: auto;
#     border: 1px solid #ccc;
#     padding: 10px;
# }
# </style>

# %%
# Explore some of these merged clusters
hdb_cluster_additional_analysis[hdb_cluster_additional_analysis['merged_cluster'] == 58]
# Out:
#      cluster                     top_words                top_words_tfidf  \
# 12        11       cloth diapering diapers   accessories covers diapering
# 45        44  diapering disposable diapers   diapers disposable diapering
# 87        86       cloth diapers diapering        diapers cloth diapering
# 94        93         cloth inserts diapers  accessories diapering diapers
# 125      124             wet cloth diapers  accessories diapering diapers
# 190      189        cloth covers diapering       diapering diapers covers
# 227      226          diaper cloth diapers           diaper cloth diapers
#
#                                     top_words_combined  merged_cluster
# 12   cloth diapering diapers accessories covers dia...              58
# 45   diapering disposable diapers diapers disposabl...              58
# 87     cloth diapers diapering diapers cloth diapering              58
# 94   cloth inserts diapers accessories diapering di...              58
# 125    wet cloth diapers accessories diapering diapers              58
# 190    cloth covers diapering diapering diapers covers              58
# 227          diaper cloth diapers diaper cloth diapers              58

# %%
# Explore some of these merged clusters
hdb_cluster_additional_analysis[hdb_cluster_additional_analysis['merged_cluster'] == 59]
# Out:
#      cluster                   top_words          top_words_tfidf  \
# 169      168  safety electrical proofing  safety electrical shock
#
#                                     top_words_combined  merged_cluster  \
# 169  safety electrical proofing safety electrical s...              59
#
#                                top_words_combined_list
# 169  [safety, electrical, proofing, safety, electri...

# %%
# Create a list of all top words associated with each merged_cluster

# Convert the combined words string to a list to make it easier to iterate over
hdb_cluster_additional_analysis['top_words_combined_list'] = (
    hdb_cluster_additional_analysis['top_words_combined'].apply(lambda x: x.split())
)

# Define a function to identify all unique words in each list
def get_all_unique_words(word_lists):
    all_words = [word for word_list in word_lists for word in word_list]
    return sorted(set(all_words))  # Optional: sort alphabetically

# Group by merged_cluster and compute both word lists and original cluster values
merged_cluster_summary = (
    hdb_cluster_additional_analysis
    .groupby('merged_cluster')
    .agg({
        'top_words_combined_list': get_all_unique_words,
        'cluster': lambda x: sorted(set(x))  # original cluster IDs
    })
    .reset_index()
)

# Turn lists into readable strings
merged_cluster_summary['unique_top_words'] = merged_cluster_summary['top_words_combined_list'].apply(lambda x: ', '.join(x))
merged_cluster_summary['original_clusters'] = merged_cluster_summary['cluster'].apply(lambda x: ', '.join(map(str, x)))

# Drop the raw list columns if you only want the final strings
merged_cluster_summary = merged_cluster_summary[['merged_cluster', 'original_clusters', 'unique_top_words']]

merged_cluster_summary.head(1000)
# Out:
#     merged_cluster                                  original_clusters  \
# 0                0   3, 12, 34, 68, 106, 110, 153, 154, 174, 190, 230
# 1                1                    10, 98, 123, 144, 149, 157, 185
# 2                2                          36, 51, 53, 193, 214, 221
# 3                3                            9, 43, 61, 75, 130, 211
# 4                4  -1, 0, 1, 5, 25, 40, 42, 56, 59, 63, 91, 104, ...
# 5                5                            4, 55, 64, 96, 135, 213
# 6                6                  137, 142, 172, 181, 199, 215, 217
# 7                7                 20, 52, 89, 92, 129, 132, 148, 204
# 8                8                                           196, 234
# 9                9  6, 8, 21, 30, 31, 49, 57, 81, 97, 115, 118, 15...
# 10              10   7, 17, 35, 77, 138, 145, 175, 176, 178, 184, 210
# 11              11                13, 54, 65, 107, 201, 202, 205, 206
# 12              12                                   58, 90, 166, 182
# 13              13                                  73, 111, 208, 218
# 14              14            28, 41, 85, 94, 117, 119, 120, 147, 171
# 15              15                                           186, 216
# 16              16                               29, 74, 82, 121, 188
# 17              17                                           102, 125
# 18              18                          50, 70, 95, 156, 173, 183
# 19              19                                            45, 224
# 20              20                                        19, 71, 108
# 21              21                                           231, 235
# 22              22                                                227
# 23              23                                                233
# 24              24                                                170
# 25              25  14, 15, 22, 48, 69, 80, 83, 88, 127, 140, 146,...
# 26              26                                            84, 223
# 27              27                                         66, 67, 87
# 28              28                     32, 78, 79, 141, 150, 220, 229
# 29              29                                                197
# 30              30                                                187
# 31              31                                                 76
# 32              32                                                 37
# 33              33                                                159
# 34              34                                           116, 180
# 35              35                                                228
# 36              36                                                 16
# 37              37                                       46, 105, 143
# 38              38                                                162
# 39              39                 23, 47, 62, 72, 100, 113, 136, 155
# 40              40                               38, 39, 99, 139, 163
# 41              41                                                192
# 42              42                                        18, 27, 207
# 43              43                                                161
# 44              44                                       33, 151, 222
# 45              45                                                131
# 46              46                                                152
# 47              47                                                128
# 48              48                                                194
# 49              49                                                 24
# 50              50                                                101
# 51              51                                                 60
# 52              52                                           114, 212
# 53              53                                                232
# 54              54                                                225
# 55              55                                    2, 26, 103, 134
# 56              56                                                169
# 57              57                                                112
# 58              58                      11, 44, 86, 93, 124, 189, 226
# 59              59                                                168
#
#                                      unique_top_words
# 0   basket, bins, chests, feeding, food, furniture...
# 1   accessories, bandana, carriers, cart, covers, ...
# 2   bath, bathing, bubble, care, feeding, hooded, ...
# 3   accessories, backpacks, bags, caddies, cloth, ...
# 4   accessories, bags, bedding, blankets, crib, gu...
# 5   baskets, boxes, furniture, gift, gifts, hand, ...
# 6   beverages, bottle, curtain, feeding, foods, fo...
# 7   accessories, breast, breastfeeding, complete, ...
# 8                 boards, book, memory, nursery, wall
# 9   accessories, bags, bunting, connectors, cup, h...
# 10  beds, changing, convertible, cribs, dressing, ...
# 11  decor, growth, letters, numbers, nursery, plaq...
# 12       audio, monitors, safety, smart, snuza, video
# 13  covers, feeding, maternity, nursery, pillow, p...
# 14  care, grooming, healthcare, kits, lotions, nai...
# 15  albums, frames, gifts, journals, nursery, picture
# 16                        bibs, burp, cloths, feeding
# 17  changing, covers, diapering, pads, portable, t...
# 18  bottle, bottles, cleaning, feeding, hands, nip...
# 19        extensions, gate, gates, pet, safety, stair
# 20  aspirators, care, colic, gas, health, nasal, r...
# 21  blanket, blue, bottle, breast, set, silicone, ...
# 22                              bag, changing, diaper
# 23                           boys, girls, hat, months
# 24                                    kitchen, safety
# 25  accessories, adapters, automotive, belt, boost...
# 26                       corner, edge, guards, safety
# 27  accessories, care, pacifier, pacifiers, relief...
# 28  covers, pants, peeball, potties, potty, seat, ...
# 29                  chairs, gliders, nursery, rocking
# 30                      mattress, nursery, protection
# 31       code, event, nursery, redeem, sent, shipping
# 32                        lab, nursery, spruce, trend
# 33             bassinet, cid, invitations, stationery
# 34        bathing, body, care, cleansers, soaps, wash
# 35                                  chair, high, seat
# 36        closet, dividers, koala, nursery, organizer
# 37          booster, feeding, highchairs, hook, seats
# 38                         dogs, feeding, play, years
# 39  cups, dishes, feeding, place, plates, solid, s...
# 40  activity, bouncers, entertainment, floor, gyms...
# 41                           nursery, sleep, soothers
# 42  diapering, holders, refills, warmers, wipe, wipes
# 43                             lamps, nursery, shades
# 44              cabinet, child, guards, locks, safety
# 45                             lights, night, nursery
# 46                         harnesses, leashes, safety
# 47                                 nursery, rug, rugs
# 48                               bed, bedding, skirts
# 49             cereal, feeding, foods, safety, straps
# 50                           mobile, mobiles, nursery
# 51                           baskets, liners, nursery
# 52              nursery, treatments, valances, window
# 53                              shoes, socks, toddler
# 54                      harness, leash, safety, wrist
# 55    accessories, care, clips, hair, headbands, ties
# 56                  bathroom, deluxe, safety, station
# 57             carters, diapering, joy, seek, stacker
# 58  accessories, cloth, covers, diaper, diapering,...
# 59                electrical, proofing, safety, shock

# %%
# Merge merged_cluster and top_words info back onto the original HDBSCAN dataset
df_hdbscan_final = hdb_scan.merge(
    hdb_cluster_additional_analysis[['cluster', 'merged_cluster', 'top_words_combined']],
    on='cluster',
    how='left'
)

df_hdbscan_final.head(100)
# Out:
#              main_category                                              title  \
# 0                     Baby                   Chicco Viaro Travel System, Teak
# 1           AMAZON FASHION  Kisbaby Four Layers Muslin Lightweight Unisex ...
# 2                     Baby  EZTOTZ Meals with Milton - USA Made Toddler & ...
# 3                     Baby                         Nuby iMonster Toddler Bowl
# 4              Amazon Home  mDesign Slim Storage Organizer Container Bin w...
# ..                     ...                                                ...
# 95                    Baby   Luxe Basics So Softy Fitted Crib Sheet, Lavender
# 96                    Baby  HIPHOP PANDA Baby Waterproof Crib Mattress Pro...
# 97  Health & Personal Care  Breast Pump Bag Backpack - Cooler and Moisture...
# 98                    Baby  phil&teds Storm Cover for Promenade, Smart Lux...
# 99                    Baby  Vaenait Baby Boys Fleece Wearable Blanket Slee...
#
#     average_rating  rating_number  \
# 0              4.6            125
# 1              5.0              2
# 2              4.4             37
# 3              4.4             52
# 4              4.5            235
# ..             ...            ...
# 95             4.5              6
# 96             4.8              7
# 97             4.6           1520
# 98             4.4             13
# 99             3.0             11
#
#                                              features  \
# 0   ['Aluminum' 'Imported'\n 'Convenient one-hand ...
# 1   ['95% Cotton, 4 Layer Muslin, Hand Wash in Col...
# 2   ['WHAT IS MILTON?: Milton is the fun way for y...
# 3   ['Makes feeding fun for baby and easier for pa...
# 4   ['SMART STORAGE: This large capacity slim bin ...
# ..                                                ...
# 95  ['100% Polyester' 'Made in US'\n 'Fitted crib ...
# 96  ['Front is 100% Bamboo - Back is 100% Waterpro...
# 97  ['🍼PORTABLE DESIGN AND LIGHT WEIGHT - It can b...
# 98  ['Polyester 50%/PVC 50%' 'Imported' 'Protects ...
# 99                                                 []
#
#                                           description  price  \
# 0   ['Product Description'\n 'For ultimate conveni...    NaN
# 1   ['You can choose bigger size If you confuse ab...    NaN
# 2                                                  []  22.99
# 3   ['When babies begin to show interest in feedin...    NaN
# 4   ["The mDesign clear storage bins for kids supp...    NaN
# ..                                                ...    ...
# 95  ['For sweet dreams and sound sleep look no fur...    NaN
# 96  ['🍃【COZY BAMBOO FIBER】 HIPHOP PANDA mattress p...  19.99
# 97                                                 []  32.98
# 98  ['Protect your child from the elements with th...    NaN
# 99                                                 []    NaN
#
#                                                images  \
# 0   {'hi_res': array(['https://m.media-amazon.com/...
# 1   {'hi_res': array(['https://m.media-amazon.com/...
# 2   {'hi_res': array(['https://m.media-amazon.com/...
# 3   {'hi_res': array(['https://m.media-amazon.com/...
# 4   {'hi_res': array(['https://m.media-amazon.com/...
# ..                                                ...
# 95  {'hi_res': array(['https://m.media-amazon.com/...
# 96  {'hi_res': array(['https://m.media-amazon.com/...
# 97  {'hi_res': array(['https://m.media-amazon.com/...
# 98  {'hi_res': array(['https://m.media-amazon.com/...
# 99  {'hi_res': array(['https://m.media-amazon.com/...
#
#                                                videos         store  ...  \
# 0   {'title': array(['Viaro Demo Video', 'Chicco V...        Chicco  ...
# 1   {'title': array([], dtype=object), 'url': arra...       Kisbaby  ...
# 2   {'title': array([], dtype=object), 'url': arra...        EZTOTZ  ...
# 3   {'title': array([], dtype=object), 'url': arra...          Nuby  ...
# 4   {'title': array([], dtype=object), 'url': arra...       mDesign  ...
# ..                                                ...           ...  ...
# 95  {'title': array([], dtype=object), 'url': arra...   Luxe Basics  ...
# 96  {'title': array(['Waterproof Crib Mattress Pro...  HIPHOP PANDA  ...
# 97  {'title': array(['MOMIGO breast pump bag fit a...        MOMIGO  ...
# 98  {'title': array([], dtype=object), 'url': arra...     phil&teds  ...
# 99  {'title': array([], dtype=object), 'url': arra...           NaN  ...
#
#                                       category_select  \
# 0   ['Baby Products' 'Strollers & Accessories' 'St...
# 1   ['Baby Products' 'Nursery' 'Bedding' 'Blankets...
# 2   EZTOTZ Meals with Milton - USA Made Toddler & ...
# 3   ['Baby Products' 'Feeding' 'Solid Feeding' 'Di...
# 4   ['Baby Products' 'Nursery' 'Furniture' 'Storag...
# ..                                                ...
# 95  ['Baby Products' 'Nursery' 'Bedding' 'Baby Bed...
# 96  ['Baby Products' 'Nursery' 'Bedding' 'Mattress...
# 97  ['Baby Products' 'Feeding' 'Breastfeeding' 'Br...
# 98  ['Baby Products' 'Strollers & Accessories' 'Ac...
# 99  ['Baby Products' 'Nursery' 'Bedding' 'Blankets...
#
#                                      categories_clean  \
# 0    strollers & accessories strollers travel systems
# 1   nursery bedding blankets & swaddling wearable ...
# 2   eztotz meals with milton - usa made toddler & ...
# 3                        feeding solid feeding dishes
# 4   nursery furniture storage & organization stora...
# ..                                                ...
# 95         nursery bedding bedding sheets crib sheets
# 96  nursery bedding mattress protection crib mattr...
# 97      feeding breastfeeding breast pump accessories
# 98  strollers & accessories accessories weather sh...
# 99  nursery bedding blankets & swaddling wearable ...
#
#                                                  text  cluster  \
# 0    strollers & accessories strollers travel systems      219
# 1   nursery bedding blankets & swaddling wearable ...       91
# 2   eztotz meals with milton - usa made toddler & ...      231
# 3                        feeding solid feeding dishes       47
# 4   nursery furniture storage & organization stora...       34
# ..                                                ...      ...
# 95         nursery bedding bedding sheets crib sheets        1
# 96  nursery bedding mattress protection crib mattr...      187
# 97      feeding breastfeeding breast pump accessories       89
# 98  strollers & accessories accessories weather sh...       97
# 99  nursery bedding blankets & swaddling wearable ...       91
#
#                                                tokens  \
# 0   [strollers, accessories, strollers, travel, sy...
# 1   [nursery, bedding, blankets, swaddling, wearab...
# 2   [eztotz, meals, milton, usa, toddler, feeding,...
# 3                   [feeding, solid, feeding, dishes]
# 4   [nursery, furniture, storage, organization, st...
# ..                                                ...
# 95  [nursery, bedding, bedding, sheets, crib, sheets]
# 96  [nursery, bedding, mattress, protection, crib,...
# 97  [feeding, breastfeeding, breast, pump, accesso...
# 98  [strollers, accessories, accessories, weather,...
# 99  [nursery, bedding, blankets, swaddling, wearab...
#
#                           top_words                      top_words_tfidf  \
# 0    strollers, accessories, travel           strollers, travel, systems
# 1        blankets, nursery, bedding        blankets, wearable, swaddling
# 2             silicone, breast, set                bottle, set, silicone
# 3            feeding, solid, dishes               feeding, solid, dishes
# 4       storage, nursery, furniture          storage, bins, organization
# ..                              ...                                  ...
# 95            bedding, sheets, crib             sheets, bedding, nursery
# 96    mattress, protection, nursery        protection, mattress, nursery
# 97      breast, pump, breastfeeding  feeding, accessories, breastfeeding
# 98  accessories, weather, strollers      accessories, strollers, shields
# 99       blankets, nursery, bedding        blankets, wearable, swaddling
#
#    missing_top_word merged_cluster  \
# 0             False              9
# 1             False              4
# 2             False             21
# 3             False             39
# 4             False              0
# ..              ...            ...
# 95            False              4
# 96            False             30
# 97            False              7
# 98            False              9
# 99            False              4
#
#                                    top_words_combined
# 0   strollers accessories travel strollers travel ...
# 1   blankets nursery bedding blankets wearable swa...
# 2             silicone breast set bottle set silicone
# 3           feeding solid dishes feeding solid dishes
# 4   storage nursery furniture storage bins organiz...
# ..                                                ...
# 95         bedding sheets crib sheets bedding nursery
# 96  mattress protection nursery protection mattres...
# 97  breast pump breastfeeding feeding accessories ...
# 98  accessories weather strollers accessories stro...
# 99  blankets nursery bedding blankets wearable swa...
#
# [100 rows x 26 columns]

# %%
# Save the following results to Excel
with pd.ExcelWriter('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/clustered-data/hdbscan-grouped-clusters.xlsx', engine='openpyxl') as writer:
    merged_cluster_summary.to_excel(writer, sheet_name='clusters-simplified', index=False)
    df_hdbscan_final.to_excel(writer, sheet_name='updated-hdbscan-dataset', index=False)

# %% [markdown]
# ## Final Groupings
#
# Now that we have analyzed the different clusters and grouped them together in order to reduce the number of overall clusters, let's combine this information to the main dataset. After doing this, we will go ahead and split out the dataset into two groups - one classified due to have a desciption in the top words for the cluster, and those which do not.
#
# Note that we will also remove the -1 cluster observations since these are cases that could not be adequately grouped.

# %%
# Use the function from earlier to flag records with results without matching top words
#df_hdbscan_final['missing_top_word'] = df_hdbscan_final.apply(lacks_top_words, axis=1)

baby_products_categorized_merged_cluster = df_hdbscan_final[(df_hdbscan_final['missing_top_word'] == False) & \
                                                            (df_hdbscan_final['cluster'] != -1)]

categorized_count = len(baby_products_categorized_merged_cluster.parent_asin.value_counts())

print(f"There are {categorized_count:,} observations with categorized values (top words in string and not cluster -1).")

require_categorization_after_merged_clusters = df_hdbscan_final[(df_hdbscan_final['missing_top_word'] == True) | \
                                                            (df_hdbscan_final['cluster'] == -1)]

uncategorized_count = len(require_categorization_after_merged_clusters.parent_asin.value_counts())

print(f"There are {uncategorized_count:,} observations with categorized values (top words in string and not cluster -1).")
# Out:
# There are 203,004 observations with categorized values (top words in string and not cluster -1).
# There are 14,720 observations with categorized values (top words in string and not cluster -1).

# %%
# Output these results to Excel for use in the next program
with pd.ExcelWriter('/Volumes/Samsung1TB/programming/data-science/baby-product-dashboard/categorized-data/hdbscan-merged-cluster-categorized.xlsx', engine='openpyxl') as writer:
    baby_products_categorized_merged_cluster.to_excel(writer, sheet_name='categorized', index=False)
    require_categorization_after_merged_clusters.to_excel(writer, sheet_name='NOT-categorized', index=False)
